# %%
import numpy as np
import pandas as pd
import datetime as dt
import datapackage
import matplotlib.pyplot as plt
import matplotlib.dates as dates

## investigating volatility linkages between oil, gas, and regionalised coal futures markets ##

## load data from Github into new frame and remove rows with absent data ##

url = 'https://raw.githubusercontent.com/joe-ascroft/phd/master/df-combined.csv'
df = pd.read_csv(url)
for col in df.columns[1:]:
    df[col] = pd.to_numeric(df[col],errors='coerce')

df = df.dropna()
print(df)

for col in df.columns[1:9]:
    df[col+'_r'] = (df[col].pct_change())
df = df.dropna()
print(df)
# Out:
#           DATE    NCF    RCF    WTI    HH  Brent  NBP_UK  GBP-USD       NBP
# 1      2/01/09  74.35  81.00  46.17  5.41  46.91   54.74   1.4453  7.911572
# 4      5/01/09  77.65  84.40  48.61  5.83  49.62   56.66   1.4708  8.333553
# 5      6/01/09  81.25  88.50  48.56  6.10  50.53   59.88   1.4919  8.933497
# 6      7/01/09  78.65  86.25  42.75  5.89  45.86   58.03   1.5111  8.768913
# 7      8/01/09  79.15  84.00  41.68  5.96  44.67   55.74   1.5202  8.473595
# ...        ...    ...    ...    ...   ...    ...     ...      ...       ...
# 4254  25/08/20  49.75  48.90  43.17  2.54  45.86   24.61   1.3148  3.235723
# 4255  26/08/20  49.70  48.95  43.21  2.52  45.64   25.10   1.3193  3.311443
# 4256  27/08/20  49.80  48.90  42.88  2.52  45.09   26.68   1.3206  3.523361
# 4257  28/08/20  50.60  52.20  42.96  2.46  45.81   28.95   1.3344  3.863088
# 4260  31/08/20  51.95  52.90  42.61  2.30  45.28   28.95   1.3379  3.873220
#
# [2856 rows x 9 columns]

# %%
## price ratio calculations 

df_returns = df[["DATE"]].copy()
df_returns["WTI_HH"] = df["WTI"]/df["HH"]
df_returns["NCF_RCF"] = df["NCF"]/df["RCF"]
df_returns["NCF_WTI"] = df["NCF"]/df["WTI"]
df_returns["NCF_HH"] = df["NCF"]/df["HH"]
df_returns["NCF_NBP"] = df["NCF"]/df["NBP"]
df_returns["NCF_B"] = df["NCF"]/df["Brent"]
df_returns["RCF_B"] = df["RCF"]/df["Brent"]
df_returns["RCF_NBP"] = df["RCF"]/df["NBP"]
df_returns["WTI_B"] = df["WTI"]/df["Brent"]
df_returns["NBP_B"] = df["NBP"]/df["Brent"]
df_returns["NBP_HH"] = df["NBP"]/df["HH"]
print(df_returns)
# Out:
#           DATE     WTI_HH   NCF_RCF   NCF_WTI     NCF_HH    NCF_NBP     NCF_B  \
# 1      2/01/09   8.534196  0.917901  1.610353  13.743068   9.397626  1.584950
# 4      5/01/09   8.337907  0.920024  1.597408  13.319039   9.317755  1.564893
# 5      6/01/09   7.960656  0.918079  1.673188  13.319672   9.094982  1.607956
# 6      7/01/09   7.258065  0.911884  1.839766  13.353141   8.969184  1.715002
# 7      8/01/09   6.993289  0.942262  1.898992  13.280201   9.340782  1.771883
# ...        ...        ...       ...       ...        ...        ...       ...
# 4254  25/08/20  16.996063  1.017382  1.152421  19.586614  15.375235  1.084823
# 4255  26/08/20  17.146825  1.015322  1.150197  19.722222  15.008563  1.088957
# 4256  27/08/20  17.015873  1.018405  1.161381  19.761905  14.134232  1.104458
# 4257  28/08/20  17.463415  0.969349  1.177840  20.569106  13.098330  1.104562
# 4260  31/08/20  18.526087  0.982042  1.219197  22.586957  13.412611  1.147306
#
#          RCF_B    RCF_NBP     WTI_B     NBP_B    NBP_HH
# 1     1.726711  10.238167  0.984225  0.168654  1.462398
# 4     1.700927  10.127733  0.979645  0.167947  1.429426
# 5     1.751435   9.906535  0.961013  0.176796  1.464508
# 6     1.880724   9.835882  0.932185  0.191210  1.488780
# 7     1.880457   9.913148  0.933065  0.189693  1.421744
# ...        ...        ...       ...       ...       ...
# 4254  1.066289  15.112543  0.941343  0.070557  1.273907
# 4255  1.072524  14.782075  0.946757  0.072556  1.314065
# 4256  1.084498  13.878794  0.950987  0.078141  1.398159
# 4257  1.139489  13.512506  0.937787  0.084328  1.570361
# 4260  1.168286  13.657885  0.941034  0.085539  1.684009
#
# [2856 rows x 12 columns]

# %%
## price ratio return calculations ##

for col in df_returns.columns[1:12]:
    df_returns[col+'_r'] = (df_returns[col].pct_change())
df_returns = df_returns.dropna()
print(df_returns)
# Out:
#           DATE     WTI_HH   NCF_RCF   NCF_WTI     NCF_HH    NCF_NBP     NCF_B  \
# 4      5/01/09   8.337907  0.920024  1.597408  13.319039   9.317755  1.564893
# 5      6/01/09   7.960656  0.918079  1.673188  13.319672   9.094982  1.607956
# 6      7/01/09   7.258065  0.911884  1.839766  13.353141   8.969184  1.715002
# 7      8/01/09   6.993289  0.942262  1.898992  13.280201   9.340782  1.771883
# 8      9/01/09   7.266071  0.920958  1.889899  13.732143   9.019865  1.731202
# ...        ...        ...       ...       ...        ...        ...       ...
# 4254  25/08/20  16.996063  1.017382  1.152421  19.586614  15.375235  1.084823
# 4255  26/08/20  17.146825  1.015322  1.150197  19.722222  15.008563  1.088957
# 4256  27/08/20  17.015873  1.018405  1.161381  19.761905  14.134232  1.104458
# 4257  28/08/20  17.463415  0.969349  1.177840  20.569106  13.098330  1.104562
# 4260  31/08/20  18.526087  0.982042  1.219197  22.586957  13.412611  1.147306
#
#          RCF_B    RCF_NBP     WTI_B  ...  NCF_RCF_r  NCF_WTI_r  NCF_HH_r  \
# 4     1.700927  10.127733  0.979645  ...   0.002312  -0.008039 -0.030854
# 5     1.751435   9.906535  0.961013  ...  -0.002114   0.047439  0.000048
# 6     1.880724   9.835882  0.932185  ...  -0.006748   0.099557  0.002513
# 7     1.880457   9.913148  0.933065  ...   0.033313   0.032192 -0.005462
# 8     1.879784   9.794002  0.916029  ...  -0.022609  -0.004788  0.034031
# ...        ...        ...       ...  ...        ...        ...       ...
# 4254  1.066289  15.112543  0.941343  ...  -0.001041  -0.015921  0.012829
# 4255  1.072524  14.782075  0.946757  ...  -0.002025  -0.001930  0.006924
# 4256  1.084498  13.878794  0.950987  ...   0.003037   0.009723  0.002012
# 4257  1.139489  13.512506  0.937787  ...  -0.048170   0.014172  0.040846
# 4260  1.168286  13.657885  0.941034  ...   0.013094   0.035113  0.098101
#
#       NCF_NBP_r   NCF_B_r   RCF_B_r  RCF_NBP_r   WTI_B_r   NBP_B_r  NBP_HH_r
# 4     -0.008499 -0.012654 -0.014932  -0.010787 -0.004653 -0.004191 -0.022547
# 5     -0.023908  0.027518  0.029694  -0.021841 -0.019019  0.052686  0.024543
# 6     -0.013832  0.066573  0.073819  -0.007132 -0.029998  0.081532  0.016574
# 7      0.041430  0.033166 -0.000142   0.007855  0.000944 -0.007935 -0.045027
# 8     -0.034356 -0.022959 -0.000358  -0.012019 -0.018258  0.011803  0.070821
# ...         ...       ...       ...        ...       ...       ...       ...
# 4254  -0.061853 -0.014928 -0.013901  -0.060876  0.001009  0.050019  0.079606
# 4255  -0.023848  0.003810  0.005848  -0.021867  0.005751  0.028334  0.031524
# 4256  -0.058255  0.014234  0.011164  -0.061107  0.004468  0.076974  0.063996
# 4257  -0.073290  0.000095  0.050707  -0.026392 -0.013881  0.079189  0.123163
# 4260   0.023994  0.038697  0.025272   0.010759  0.003462  0.014359  0.072371
#
# [2855 rows x 23 columns]

# %%
df_returns.to_csv('df_rr.csv',index=False)
